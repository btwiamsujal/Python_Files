# %% [markdown]
# <a href="https://colab.research.google.com/github/btwiamsujal/Python_Files/blob/main/Tic_Tac_Toe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Tic-Tac-Toe code

def print_board(board):
  print("-------------")
  for i in range(3):
    print("|", board[i*3], "|", board[i*3 + 1], "|", board[i*3 + 2], "|")
    print("-------------")

def check_win(board, player):
  # Check rows, columns, and diagonals
  for i in range(3):
    if all(board[i*3 + j] == player for j in range(3)):
      return True
    if all(board[j*3 + i] == player for j in range(3)):
      return True
  if all(board[i*4] == player for i in range(3)):
      return True
  if all(board[i*2+2] == player for i in range(3)):
      return True
  return False

def check_draw(board):
  return all(cell != ' ' for cell in board)

def play_tic_tac_toe():
  board = [' '] * 9
  first_player = input("Enter the player name: ")
  second_player = input("Enter the player name: ")
  while True:
    print_board(board)
    move = int(input(f"Player {first_player}, enter your move (1-9): ")) - 1

    if 0 <= move <= 8 and board[move] == ' ':
      board[move] = first_player
    else:
      print("Invalid move. Try again.")
      continue

    if check_win(board, first_player):
      print_board(board)
      print(f"Player {first_player} wins!")
      break
    elif check_draw(board):
      print_board(board)
      print("It's a draw!")
      break
    else:
      first_player = 'O' if first_player == 'X' else second_player

if __name__ == "__main__":
  play_tic_tac_toe()
# Out:
# Enter the player name: Player 1
# Enter the player name: Player 2
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# Player Player 1, enter your move (1-9): 1
# -------------
# | Player 1 |   |   |
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# Player Player 2, enter your move (1-9): 2
# -------------
# | Player 1 | Player 2 |   |
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# Player Player 2, enter your move (1-9): 3
# -------------
# | Player 1 | Player 2 | Player 2 |
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# Player Player 2, enter your move (1-9): 4
# -------------
# | Player 1 | Player 2 | Player 2 |
# -------------
# | Player 2 |   |   |
# -------------
# |   |   |   |
# -------------
# Player Player 2, enter your move (1-9): 5
# -------------
# | Player 1 | Player 2 | Player 2 |
# -------------
# | Player 2 | Player 2 |   |
# -------------
# |   |   |   |
# -------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-bd517a54e84f> in <cell line: 0>()
#      49
#      50 if __name__ == "__main__":
# ---> 51   play_tic_tac_toe()
#
# <ipython-input-2-bd517a54e84f> in play_tic_tac_toe()
#      29   while True:
#      30     print_board(board)
# ---> 31     move = int(input(f"Player {first_player}, enter your move (1-9): ")) - 1
#      32
#      33     if 0 <= move <= 8 and board[move] == ' ':
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
37
def print_board(board):
    print("-------------")
    for i in range(3):
        print("|", board[i*3], "|", board[i*3 + 1], "|", board[i*3 + 2], "|")
        print("-------------")

def check_win(board, player):
    for i in range(3):
        if all(board[i*3 + j] == player for j in range(3)):
            return True
        if all(board[j*3 + i] == player for j in range(3)):
            return True
    if all(board[i*4] == player for i in range(3)):
        return True
    if all(board[i*2+2] == player for i in range(3)):
        return True
    return False

def check_draw(board):
    return all(cell != ' ' for cell in board)

def play_tic_tac_toe():
    player1 = input("Enter name of Player 1 (X): ")
    player2 = input("Enter name of Player 2 (O): ")
    board = [' '] * 9
    players = {'X': f'\033[91mX\033[0m', 'O': f'\033[92mO\033[0m'}  # Red for X, Green for O
    names = {'X': player1, 'O': player2}
    turn = 0

    while True:
        print_board(board)
        move = int(input(f"{names[list(players.keys())[turn % 2]]}, enter your move (1-9): ")) - 1

        if 0 <= move <= 8 and board[move] == ' ':
            board[move] = players[list(players.keys())[turn % 2]]
        else:
            print("Invalid move. Try again.")
            continue

        if check_win(board, players[list(players.keys())[turn % 2]]):
            print_board(board)
            print(f"Congratulations {names[list(players.keys())[turn % 2]]}! You win!")
            break
        elif check_draw(board):
            print_board(board)
            print("It's a draw!")
            break
        else:
            turn += 1

if __name__ == "__main__":
    play_tic_tac_toe()
# Out:
# Enter name of Player 1 (X): Player 1
# Enter name of Player 2 (O): Player 2
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# Player 1, enter your move (1-9): 1
# -------------
# | X |   |   |
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# Player 2, enter your move (1-9): 4
# -------------
# | X |   |   |
# -------------
# | O |   |   |
# -------------
# |   |   |   |
# -------------
# Player 1, enter your move (1-9): 2
# -------------
# | X | X |   |
# -------------
# | O |   |   |
# -------------
# |   |   |   |
# -------------
# Player 2, enter your move (1-9): 3
# -------------
# | X | X | O |
# -------------
# | O |   |   |
# -------------
# |   |   |   |
# -------------
# Player 1, enter your move (1-9): 7
# -------------
# | X | X | O |
# -------------
# | O |   |   |
# -------------
# | X |   |   |
# -------------
# Player 2, enter your move (1-9): 9
# -------------
# | X | X | O |
# -------------
# | O |   |   |
# -------------
# | X |   | O |
# -------------
# Player 1, enter your move (1-9): 6
# -------------
# | X | X | O |
# -------------
# | O |   | X |
# -------------
# | X |   | O |
# -------------
# Player 2, enter your move (1-9): 5
# -------------
# | X | X | O |
# -------------
# | O | O | X |
# -------------
# | X |   | O |
# -------------
# Player 1, enter your move (1-9): 8
# -------------
# | X | X | O |
# -------------
# | O | O | X |
# -------------
# | X | X | O |
# -------------
# It's a draw!
